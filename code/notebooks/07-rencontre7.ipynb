# %% [markdown]
# # Exercices de la Semaine 7 : Examen formatif

# %% [markdown]
# Cette semaine est consacrée à la préparation de l'examen intra.\n\nIl n'y a pas de nouveaux exercices, l'objectif est de réviser la matière des semaines 1 à 6 et de faire l'examen formatif fourni par votre enseignant.
