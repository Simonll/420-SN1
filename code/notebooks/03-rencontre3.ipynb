# %% [markdown]
# ## Fonction

# %% [markdown]
# ### Fonction simple

# %%
def double(x):
    return 2 * x

# %% [markdown]
# ### Indentation

# %%
def double(x):
    y = 2 * x  # Cette ligne fait partie de la fonction (indentée)
    return y   # Cette ligne fait aussi partie de la fonction (indentée)
z = 3          # Cette ligne n'est pas indentée, elle ne fait pas partie de la fonction

# %% [markdown]
# ### Appelle d'une fonction

# %%
def double(x):
    return 2 * x
double(5)  # Appel de la fonction en lui passant la valeur 5

# %%
resultat = double(5)  # Appel de la fonction et stockage de la valeur retournée dans la variable 'resultat'

# %%
resultat1 = double(5)  # Appel de la fonction avec la valeur 5
resultat2 = double(10) # Appel de la fonction avec la valeur 10
resultat3 = double(2)  # Appel de la fonction avec la valeur 2

# %%
a = 5
resultat = double(a)  # Appel de la fonction en lui passant la valeur contenue dans la variable 'a'

# %% [markdown]
# ## Paramètres

# %%
def nombre_pi():
    return 3.14159

def carre(x):
    return x * x

def puissance(base, exposant):
    return base ** exposant

# %%
pi = nombre_pi()       # Appel de la fonction sans paramètre
carre_de_5 = carre(5)  # Appel de la fonction avec un paramètre (x=5)

# %%
resultat1 = puissance(2, 3)  # Appel de la fonction avec base=2 et exposant=3 (retourne 8)
resultat2 = puissance(3, 2)  # Appel de la fonction avec base=3 et exposant=2 (retourne 9)

# %% [markdown]
# ### Paramètres avec des valeurs par défaut

# %%
def puissance(base, exposant=2):
    return base ** exposant

resultat1 = puissance(5)     # retourne 25, car exposant prend la valeur par défaut 2
resultat2 = puissance(5, 3)  # retourne 125, car exposant prend la valeur 3 fournie lors de l'appel

# %% [markdown]
# ### Une liste comme paramètre

# %%
def calculer_moyenne(notes):
    """
    Calcule la moyenne de 3 notes.

    Paramètre :
    notes (list) : Une liste contenant 3 notes numériques.

    Retourne :
    float : La moyenne des 3 notes.
    """
    return (notes[0] + notes[1] + notes[2]) / 3

notes_alice = [14, 17, 12]
notes_bob   = [9,  11, 15]

moyenne_alice = calculer_moyenne(notes_alice)
moyenne_bob   = calculer_moyenne(notes_bob)

print(f"Moyenne d'Alice : {round(moyenne_alice, 2)}")
print(f"Moyenne de Bob  : {round(moyenne_bob, 2)}")

# %% [markdown]
# ## Les retours

# %%
def diviser(a, b):
    quotient = a / b
    reste = a % b
    return quotient, reste

q, r = diviser(10, 3)

# %%
def plus_grand(a, b):
    if a > b:
        return a
    else:
        return b

# %% [markdown]
# ### Fonction sans retour

# %%
def salutation(nom, age):
    print("Bonjour")
    print(f"Je m'appelle {nom}, j'ai {age} ans")

# %%
def salutation(nom, age):
    print("Bonjour")
    print(f"Je m'appelle {nom}, j'ai {age} ans")
    return None

# %%
resultat = salutation("Gustave", 32) # Affiche la salutation, puis stocke `None` dans `resultat`
print(resultat)                      # Affiche la valeur de `resultat`, qui est `None`
print(salutation("Sciel", 32))       # Affiche la salutation, puis affiche la valeur de retour `None`

# %%
# bonne utilisation :
salutation("Gustave", 32)  # Affiche la salutation

# mauvaise utilisation :
print(salutation("Gustave", 32))  # Affiche la salutation, puis `None`

# %%
def salutation(nom, age):
    return f"Bonjour\nJe m'appelle {nom}, j'ai {age} ans."

message = salutation("Gustave", 32)  # Stocke la chaîne de caractères retournée par la fonction
                                     # dans la variable 'message'

print(message)  # Affiche le message stocké dans la variable 'message'

# %% [markdown]
# ## Portée

# %% [markdown]
# ### Portée globale

# %%
x = 10  # Variable globale

def ma_fonction():
    print(f"Valeur de x dans la fonction : {x}")  # x est accessible ici

ma_fonction()
print(f"Valeur de x en dehors de la fonction : {x}")

# %% [markdown]
# ### Portée locale

# %%
def ma_fonction(z):  # z a une portée locale
    y = 5            # y est une variable locale
    print(f"Valeur de y dans la fonction : {y}")
    print(f"Valeur de z dans la fonction : {z}")

ma_fonction(5)
ma_fonction(4)

print(y)  # Erreur : y n'existe pas en dehors de la fonction
print(z)  # Erreur : z n'existe pas en dehors de la fonction

# %% [markdown]
# ### Une variable globale et une variable locale qui portent le même nom!

# %%
x = 10  # Variable globale

def ma_fonction():
    x = 5  # Nouvelle variable locale, différente de la globale
    print(f"Valeur locale de x : {x}")  # Affiche 5

ma_fonction()
print(f"Valeur globale de x : {x}")  # Affiche 10

# %% [markdown]
# ## Le DRY (Don't Repeat Yourself)

# %% [markdown]
# ### Étape 1 : Identifier les éléments qui changent

# %%
def calculer_poids(m, g):
    poids = m * g
    return poids

# %% [markdown]
# ### Étape 2 : Extraire la fonction de calcul (avec retour)

# %%
def calculer_poids(m, g):
    poids = m * g
    return poids

masse_spationaute = 75

# On utilise maintenant la fonction pour obtenir les valeurs
p_terre = calculer_poids(masse_spationaute, 9.81)
print(f"Sur l'astre Terre, le poids est de {p_terre:.2f} N.")

p_mars = calculer_poids(masse_spationaute, 3.71)
print(f"Sur l'astre Mars, le poids est de {p_mars:.2f} N.")

p_lune = calculer_poids(masse_spationaute, 1.62)
print(f"Sur l'astre Lune, le poids est de {p_lune:.2f} N.")

# %% [markdown]
# ### Résultat intermédiaire : intégration du calcul

# %%
def afficher_poids_astre(nom_astre, m, g):
    # Appel à l'autre fonction pour faire le calcul
    poids_calcule = calculer_poids(m, g)

    # Affichage du résultat
    print(f"Sur l'astre {nom_astre}, le poids est de {poids_calcule:.2f} N.")

# %% [markdown]
# ### Fonction 2 : affichage du poids

# %%
# --- Définition des fonctions ---

def calculer_poids(m, g):
    poids = m * g
    return poids

def afficher_poids_astre(nom_astre, m, g):
    poids_calcule = calculer_poids(m, g)
    print(f"Sur l'astre {nom_astre}, le poids est de {poids_calcule:.2f} N.")

# --- Script principal ---

masse_spationaute = 75

afficher_poids_astre("Terre", masse_spationaute, 9.81)
afficher_poids_astre("Mars", masse_spationaute, 3.71)
afficher_poids_astre("Lune", masse_spationaute, 1.62)

# %%
### Étape 2 : Extraire la fonction d'affichage (sans retour)

# %%
def afficher_poids_astre(nom_astre, m, g):
    # Appel à l'autre fonction pour faire le calcul
    poids_calcule = calculer_poids(m, g)

    # Affichage du résultat
    print(f"Sur l'astre {nom_astre}, le poids est de {poids_calcule:.2f} N.")

# %% [markdown]
# ### Résultat final : intégration de l'affichage

# %%
# --- Définition des fonctions ---

def calculer_poids(m, g):
    poids = m * g
    return poids

def afficher_poids_astre(nom_astre, m, g):
    poids_calcule = calculer_poids(m, g)
    print(f"Sur l'astre {nom_astre}, le poids est de {poids_calcule:.2f} N.")

# --- Script principal ---

masse_spationaute = 75

afficher_poids_astre("Terre", masse_spationaute, 9.81)
afficher_poids_astre("Mars", masse_spationaute, 3.71)
afficher_poids_astre("Lune", masse_spationaute, 1.62)

# %% [markdown]
# ### Variante avec des listes parallèles

# %%
# --- Définition des fonctions (inchangées) ---

def calculer_poids(m, g):
    poids = m * g
    return poids

def afficher_poids_astre(nom_astre, m, g):
    poids_calcule = calculer_poids(m, g)
    print(f"Sur l'astre {nom_astre}, le poids est de {poids_calcule:.2f} N.")

# --- Script principal avec des listes parallèles ---

masse_spationaute = 75
noms_astres = ["Terre", "Mars", "Lune"]
gravites    = [9.81, 3.71, 1.62]

afficher_poids_astre(noms_astres[0], masse_spationaute, gravites[0])
afficher_poids_astre(noms_astres[1], masse_spationaute, gravites[1])
afficher_poids_astre(noms_astres[2], masse_spationaute, gravites[2])

# %% [markdown]
# ## Les commentaires

# %%
# Ceci est un commentaire sur une seule ligne
def energie_cinetique(masse, vitesse): # Ceci est un commentaire en fin de ligne
    """
    Calcule l'énergie cinétique d'un objet en mouvement.

    Paramètres :
    masse (float) : Masse de l'objet en kilogrammes (kg)
    vitesse (float) : Vitesse de l'objet en mètres par seconde (m/s)

    Retourne :
    float : Énergie cinétique en Joules (J)

    Exemple d'utilisation :
    energie_cinetique(10, 5)
    """
    nb_joules = 0.5 * masse * pow(vitesse,2)
    return nb_joules

# Exemple avec différentes valeurs
objet1 = energie_cinetique(2, 3) # Masse de 2 kg, vitesse de 3 m/s
objet2 = energie_cinetique(5, 7) # Masse de 5 kg, vitesse de 7 m/s

# Affichage des résultats
print("Énergie cinétique de l'objet 1 :", objet1, "Joules")
print("Énergie cinétique de l'objet 2 :", objet2, "Joules")

# %% [markdown]
# ## La pile d'appels de fonctions

# %% [markdown]
# ### Les appels

# %%
def ajouter(x, y):
    return x + y

def multiplier(x, y):
    return x * y

def calculer_expression(a, b, c):
    somme = ajouter(a, b)
    resultat = multiplier(somme, c)
    return resultat

valeur = calculer_expression(2, 3, 4)
print(valeur)  # Affiche 20

# %% [markdown]
# ### La pile d'appels

# %%
def fonction_a():
    print("Fonction A")
    fonction_b()

def fonction_b():
    print("Fonction B")

fonction_a()

# %% [markdown]
# ### Le débogueur

# %%
def ajouter(x, y):
    return x + y

def multiplier(x, y):
    return x * y

def calculer_expression(a, b, c):
    somme = ajouter(a, b)
    resultat = multiplier(somme, c)
    return resultat

valeur = calculer_expression(2, 3, 4)
print(valeur)  # Affiche 20

# %% [markdown]
# ### Éviter la répétition : créez des fonctions!

# %%
masse_spationaute = 75

# Calcul et affichage pour la Terre
poids_terre = masse_spationaute * 9.81
print(f"Sur l'astre Terre, le poids est de {poids_terre:.2f} N.")

# Calcul et affichage pour Mars
poids_mars = masse_spationaute * 3.71
print(f"Sur l'astre Mars, le poids est de {poids_mars:.2f} N.")

# Calcul et affichage pour la Lune
poids_lune = masse_spationaute * 1.62
print(f"Sur l'astre Lune, le poids est de {poids_lune:.2f} N.")

# %% [markdown]
# # Exercices de la Semaine 3 : Création de fonctions

# %% [markdown]
# ## Exercices de compréhension

# %% [markdown]
# ### Exercice - Portée des variables
#
# Soit le code suivant :
# ```python
# def calcul_complexe(a, b, c):
#     x = a ** b
#     y = c * (b - a)
#     return x + y
#
# x = 5
# calcul_complexe(2, 3, 4)
# print(x)
# ```
# 1. Combien vaut `x` dans `calcul_complexe`? (ligne 2)
# 2. Combien vaut `x` dans le script principal? (ligne 6)
# 3. S’agit‑il de la même variable `x` ou de deux variables distinctes? Expliquez.

# %% [markdown]
# #### Solution
# 1.  **Dans `calcul_complexe`, `x` vaut 8.** Le `x` à la ligne 2 est une variable **locale** à la fonction. Sa valeur est `a ** b`, soit `2 ** 3 = 8`.
# 2.  **Dans le script principal, `x` vaut 5.** Le `x` à la ligne 6 est une variable **globale**. Sa valeur est initialisée à 5 et n'est jamais modifiée par la suite.
# 3.  Il s'agit de **deux variables distinctes**. La variable `x` locale (dans la fonction) "masque" la variable globale `x` (à l'extérieur) mais ne la modifie pas. La portée de la variable locale est limitée à l'intérieur de la fonction `calcul_complexe`.

# %% [markdown]
# ### Exercice - Trace avec fonction
#
# Sans exécuter le code, qu'affichera le programme ci-dessous? Tracez son exécution.

# %%
def fonction_lineaire(a, x, b) :
    print("appel de la fonction")
    z = a * x + b
    return z

x = 5
y = 10
z = 2
r = fonction_lineaire(x, z, y) # Attention à l'ordre des paramètres
x = x - 3
print(r, x)

# Sortie attendue :
# appel de la fonction
# 20 2

# %% [markdown]
# ### Exercice - Trace avec fonctions avec paramètres
#
# Sans exécuter le code, qu'affichera le programme ci-dessous? Tracez son exécution.

# %%
def ajoute_cinq(x):
    return x + 5

def carre(x):
    return x * x

def calcul_final(a, b):
    print("appel de calcul_final")
    return carre(a) + ajoute_cinq(b)

x = 2
resultat = calcul_final(x, 3)
print(resultat)

# Sortie attendue :
# appel de calcul_final
# 12

# %% [markdown]
# ## Exercices de création

# %% [markdown]
# ### Exercice - Conversion Celsius → Fahrenheit
#
# Écrivez une fonction `celsius_vers_fahrenheit(celsius)` qui reçoit une température en °C et retourne sa valeur en °F grâce à la formule :
# °F = (°C × 9/5) + 32
#
# Testez votre fonction à l'aide des instructions ci-dessous :
# ```python
# print(celsius_vers_fahrenheit(0)) # 32.0
# print(celsius_vers_fahrenheit(100)) # 212.0
# ```

# %%
def celsius_vers_fahrenheit(celsius):
    """Convertit une température de Celsius en Fahrenheit."""
    return (celsius * 9/5) + 32

# Tests
print(celsius_vers_fahrenheit(0))
print(celsius_vers_fahrenheit(100))

# %% [markdown]
# ### Exercice - Aire d’un rectangle
#
# Écrivez une fonction `aire_rectangle(longueur, largeur)` qui calcule et **retourne** l’aire d’un rectangle.
# Puis, appelez la fonction pour afficher l’aire d’un rectangle de 5 m × 3 m.

# %%
def aire_rectangle(longueur, largeur):
    """Calcule l'aire d'un rectangle."""
    return longueur * largeur

print(f"L'aire d'un rectangle de 5 x 3 est : {aire_rectangle(5,3)}")

# %% [markdown]
# ### Exercice - Réutilisation de fonctions
#
# 1. Écrivez une fonction `aire_rectangle(longueur, largeur)` qui calcule et **retourne** l’aire d’un rectangle.
# 2. Écrivez une deuxième fonction `volume_prisme(longueur, largeur, hauteur)` qui calcule et **retourne** le volume d’un prisme rectangulaire.
#    👉 Cette deuxième fonction doit **réutiliser** (appeler) votre fonction `aire_rectangle` pour calculer la base du prisme avant de la multiplier par la hauteur.
# 3. Testez vos fonctions en affichant :
#    - l’aire d’un rectangle de 5×3
#    - le volume d’un prisme de 5×3×4

# %%
def aire_rectangle(longueur, largeur):
    """Calcule l'aire d'un rectangle."""
    return longueur * largeur

def volume_prisme(longueur, largeur, hauteur):
    """Calcule le volume d'un prisme rectangulaire en réutilisant aire_rectangle."""
    aire_base = aire_rectangle(longueur, largeur)
    return aire_base * hauteur

# Tests
print(f"L'aire d'un rectangle de 5x3 est : {aire_rectangle(5, 3)}")
print(f"Le volume d'un prisme de 5x3x4 est : {volume_prisme(5, 3, 4)}")

# %% [markdown]
# ### Exercice - ÉNERGIE CINÉTIQUE
#
# Pour cet exercice, vous devez créer un module (un fichier `.py`) et un script (un autre fichier `.py`).
#
# 1. Dans le module, nommé `sciences_nature`, écrivez une fonction permettant de calculer l'énergie cinétique E en utilisant la formule : E = (m × v²) / 2, où m est la masse et v la vitesse.
# 2. Dans le script (un autre fichier `.py`) : importez le module, appelez votre fonction avec différentes valeurs, affichez les résultats.
#
# **Note pour le Notebook :** Comme on ne peut pas créer de fichiers séparés ici, on va simuler le comportement en définissant la fonction dans une cellule et en l'appelant dans une autre.

# %%
# Cette cellule simule le fichier 'sciences_nature.py'

def energie_cinetique(masse, vitesse):
    """
    Calcule l'énergie cinétique d'un objet en mouvement.

    Paramètres :
    masse (float) : Masse de l'objet en kilogrammes (kg)
    vitesse (float) : Vitesse de l'objet en mètres par seconde (m/s)

    Retourne :
    float : Énergie cinétique en Joules (J)
    """
    return 0.5 * masse * (vitesse ** 2)

# %%
# Cette cellule simule le script principal qui importe et utilise le module

# import sciences_nature <- C'est ce qu'on ferait dans un vrai script

# Exemple avec différentes valeurs
objet1_joules = energie_cinetique(2, 3) # Masse de 2 kg, vitesse de 3 m/s
objet2_joules = energie_cinetique(5, 7) # Masse de 5 kg, vitesse de 7 m/s

# Affichage des résultats
print(f"Énergie cinétique de l'objet 1 : {objet1_joules} Joules")
print(f"Énergie cinétique de l'objet 2 : {objet2_joules} Joules")

# %% [markdown]
# ### Exercice - FORCE GRAVITATIONNELLE
#
# Dans le même module créé à l'exercice précédent, ajoutez une fonction permettant de calculer la force gravitationnelle en utilisant la loi de la gravitation universelle de Newton dont la formule est :
# F = (G × m1 × m2) / r²
# où :
# - G = 6.674 × 10⁻¹¹ (constante gravitationnelle),
# - m1 et m2 sont les masses en kg,
# - r est la distance en mètres.

# %%
# Cette cellule simule l'ajout de la fonction au fichier 'sciences_nature.py'
G = 6.674e-11

def force_gravitationnelle(m1, m2, r):
    """Calcule la force gravitationnelle entre deux objets."""
    if r == 0:
        return float('inf') # La force est infinie si la distance est nulle
    return (G * m1 * m2) / (r ** 2)

# Test avec la Terre et la Lune
masse_terre = 5.972e24  # kg
masse_lune = 7.342e22   # kg
distance_terre_lune = 3.844e8 # mètres

force = force_gravitationnelle(masse_terre, masse_lune, distance_terre_lune)
print(f"Force gravitationnelle entre la Terre et la Lune : {force:.2e} N")

# %% [markdown]
# ### Exercice - Bonjour
#
# 1. Écrivez une fonction `dire_bonjour(prenom)` qui reçoit un prénom en paramètre et affiche un message de salutation personnalisé.
# 2. Déclarez une liste de prénoms, puis appelez `dire_bonjour` pour chaque élément en accédant aux éléments par leur index.

# %%
def dire_bonjour(prenom):
    """Affiche une salutation personnalisée."""
    print(f"Bonjour, {prenom}!")

prenoms = ["Chatmouraï", "Astro", "Peluche"]

dire_bonjour(prenoms[0])
dire_bonjour(prenoms[1])
dire_bonjour(prenoms[2])

# %% [markdown]
# ### Exercice - Refactorisation du code - Umbrella Corporation
#
# Améliorez le code ci-dessous en déclarant des listes parallèles et en définissant une fonction qui sera appelée pour chaque échantillon.

# %%
# --- Listes parallèles contenant les données ---
noms = ["Virus-T", "Virus-G", "Uroboros"]
temperatures = [37.0, 39.5, 40.0]
pH_valeurs = [6.2, 5.8, 7.0]
mutations = ["Stable", "Instable", "Agressive"]
specifiques = ["Contagiosité : Élevée", "Capacité Régénérative : Extrême", "Compatibilité Hôte : Faible"]

# --- Définition de la fonction d'affichage ---
def afficher_echantillon(nom, temp, ph, mutation, specifique):
    print(f"Échantillon : {nom}")
    print(f"Température : {temp}°C")
    print(f"pH : {ph}")
    print(f"Mutation Cellulaire : {mutation}")
    print(specifique)
    print("---------------")

# --- Script principal ---
print("Rapport - Résultats des expériences Umbrella Corporation")

afficher_echantillon(noms[0], temperatures[0], pH_valeurs[0], mutations[0], specifiques[0])
afficher_echantillon(noms[1], temperatures[1], pH_valeurs[1], mutations[1], specifiques[1])
afficher_echantillon(noms[2], temperatures[2], pH_valeurs[2], mutations[2], specifiques[2])

print("Fin du rapport. Données classifiées - Niveau d'accès : Alpha")

# %% [markdown]
# ### Exercice - Refactorisation du code - Calcul de densité
#
# Réécrivez le programme ci-dessous en utilisant des listes parallèles et une fonction pour éviter la répétition du code.

# %%
# --- Données initiales ---
masses_g = [135, 270, 92]
volumes_cm3 = [84, 151, 113]

# --- Fonction de calcul ---
def calculer_densite(masse_g, volume_cm3):
    """Calcule la densité en kg/m³ à partir de g et cm³."""
    masse_kg = masse_g / 1000
    volume_m3 = volume_cm3 / 1_000_000
    densite = masse_kg / volume_m3
    return densite

# --- Script principal ---
densite1 = calculer_densite(masses_g[0], volumes_cm3[0])
densite2 = calculer_densite(masses_g[1], volumes_cm3[1])
densite3 = calculer_densite(masses_g[2], volumes_cm3[2])

# --- Affichage des résultats ---
print(f"Densité 1 : {densite1:.2f} kg/m3")
print(f"Densité 2 : {densite2:.2f} kg/m3")
print(f"Densité 3 : {densite3:.2f} kg/m3")

# %% [markdown]
# ### Exercice - Une question de nanosecondes
#
# En observant les instructions 15 à 19 du code ci-dessous, que représente le nombre contenu dans la variable `mystere`?

# %%
import time

def calcul_intensif():
    '''
    Cette fonction prend un certain temps pour s'exécuter.
    '''
    total = 0
    for i in range(1, 20000000):  # 20 millions d'itérations
        total += i ** 0.5
    return total

tempA = time.monotonic_ns()
calcul_intensif()
tempB = time.monotonic_ns()

mystere = tempB - tempA # Expression intéressante
print(f"La variable 'mystere' contient : {mystere}")

# %% [markdown]
# #### Solution
# La variable `mystere` représente le **temps d'exécution** de la fonction `calcul_intensif()` en nanosecondes.
#
# - `tempA` enregistre le temps juste **avant** l'appel de la fonction.
# - `tempB` enregistre le temps juste **après** que la fonction a terminé son exécution.
# - La différence `tempB - tempA` donne donc la durée totale écoulée pendant l'exécution de la fonction.

# %% [markdown]
# ## Exercices sur papier

# %% [markdown]
# ### Exercice - Force centripète
#
# Écrivez un programme qui calcule la force nécessaire (Fc) pour maintenir un objet en mouvement circulaire (comme une voiture dans un virage).
#
# **Formule :** Fc = (m ⋅ v²) / r
#
# **Contraintes techniques :**
# - Définissez une fonction nommée `calculer_force_centripete` recevant 3 paramètres : la masse, la vitesse et le rayon.
# - La fonction doit retourner la valeur calculée (elle ne doit pas faire de `print` elle-même).
# - Appelez la fonction, récupérez la valeur retournée dans une variable, puis affichez le résultat final avec deux décimales.
#
# **Exemple attendu (pour m=1200, v=25, r=50) :**
# ```
# Paramètres : 1200 kg, 25 m/s, 50 m
#
# La force centripète résultante est de 15000.00 N
# ```

# %%
def calculer_force_centripete(masse, vitesse, rayon):
    """Calcule la force centripète."""
    if rayon == 0:
        return float('inf')
    return (masse * vitesse**2) / rayon

# Données
m = 1200
v = 25
r = 50

# Appel de la fonction
force = calculer_force_centripete(m, v, r)

# Affichage
print(f"Paramètres : {m} kg, {v} m/s, {r} m")
print()
print(f"La force centripète résultante est de {force:.2f} N")
